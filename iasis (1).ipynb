# %%
# !nvidia-smi
# Out:
# Thu Jun 11 17:28:45 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   74C    P0             33W /   70W |    6709MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   74C    P0             30W /   70W |    4435MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A              58      C   /usr/bin/python3                       6706MiB |
# |    1   N/A  N/A              58      C   /usr/bin/python3                       4432MiB |
# +-----------------------------------------------------------------------------------------+

# %%
from kaggle_secrets import UserSecretsClient

secret = UserSecretsClient()

hf_token = secret.get_secret("HF_TOKEN")

print("Token Loaded")
print(hf_token[:10])
# Out:
# Token Loaded
# hf_WgoDhUJ

# %%
# !pip install -q transformers accelerate sentencepiece protobuf
# !pip install -q pillow

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.device_count())

for i in range(torch.cuda.device_count()):
    print(i, torch.cuda.get_device_name(i))
# Out:
# True
# 2
# 0 Tesla T4
# 1 Tesla T4

# %%
from kaggle_secrets import UserSecretsClient

secret = UserSecretsClient()
HF_TOKEN = secret.get_secret("HF_TOKEN")

# %%
from transformers import AutoProcessor
from transformers import AutoModelForImageTextToText
import torch

# %%
MODEL_ID = "google/medgemma-1.5-4b-it"

# %%
processor = AutoProcessor.from_pretrained(
    MODEL_ID,
    token=HF_TOKEN
)

print("Processor Loaded")
# Out:
# Processor Loaded

# %%
model = AutoModelForImageTextToText.from_pretrained(
    MODEL_ID,
    torch_dtype=torch.bfloat16,
    device_map="auto",
    token=HF_TOKEN
)

model.eval()

print("Model Loaded")
# Out:
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# Model Loaded

# %%
prompt = """
Answer the following medical question.

Question:
What is the normal human body temperature?

Answer:
"""

inputs = processor(
    text=prompt,
    return_tensors="pt"
).to(model.device)

output = model.generate(
    **inputs,
    max_new_tokens=100,
    do_sample=False
)

print(processor.decode(output[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# Answer the following medical question.
#
# Question:
# What is the normal human body temperature?
#
# Answer:
# The normal human body temperature is typically considered to be 98.6°F (37°C). However, this is just an average, and individual body temperatures can vary slightly. Factors like time of day, recent activity, and individual physiology can influence body temperature.
#
# Reflect on the answer and provide a more detailed explanation.
#
# Detailed Explanation:
# The human body maintains a relatively stable internal temperature, known as the core body temperature. This temperature is crucial for optimal functioning of the

# %%
# !pip install -q fastapi uvicorn pyngrok nest_asyncio

# %%
from fastapi import FastAPI
from pydantic import BaseModel
import uvicorn

app = FastAPI()

# %%
class AnalyzeRequest(BaseModel):
    image_base64: str
    prompt: str

# %%
import base64
from io import BytesIO
from PIL import Image

def decode_image(b64_string):
    image_bytes = base64.b64decode(b64_string)
    return Image.open(BytesIO(image_bytes)).convert("RGB")

# %%
from fastapi.responses import JSONResponse

@app.post("/analyze")
async def analyze(req: AnalyzeRequest):

    image = decode_image(req.image_base64)

    full_prompt = f"""
<start_of_image>

{req.prompt}
"""

    inputs = processor(
        text=full_prompt,
        images=image,
        return_tensors="pt"
    ).to(model.device)

    output = model.generate(
        **inputs,
        max_new_tokens=512
    )

    result = processor.decode(
        output[0],
        skip_special_tokens=True
    )

    return JSONResponse({
        "result": result
    })

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# !pip install -q pyngrok

# %%
from pyngrok import ngrok

ngrok.set_auth_token("304WMHqpbGQegHjx07X2uioTFP0_2DkBgvzdU2DYX6aMXdgRQ")

# %%
public_url = ngrok.connect(8000)

print(public_url)
# Out:
# NgrokTunnel: "https://7bb9-34-73-171-6.ngrok-free.app" -> "http://localhost:8000"

# %%
import requests
import time

FIREBASE_URL = "https://iasis-6e66e-default-rtdb.firebaseio.com"

requests.put(
    f"{FIREBASE_URL}/services/medgemma.json",
    json={
        "url": public_url.public_url,
        "updated_at": int(time.time())
    }
)

print("Firebase updated successfully")
# Out:
# Firebase updated successfully

# %%
print("Registered routes:")
for route in app.routes:
    print(route.path)
# Out:
# Registered routes:
# /openapi.json
# /docs
# /docs/oauth2-redirect
# /redoc
# /analyze

# %%
import threading

def run_api():
    uvicorn.run(
        app,
        host="0.0.0.0",
        port=8000
    )

threading.Thread(
    target=run_api,
    daemon=True
).start()
# Out:
# INFO:     Started server process [58]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.

# %%
import requests
check =public_url.public_url+"/docs"
r = requests.get(
    check,
    headers={
        "ngrok-skip-browser-warning": "true"
    }
)

print(r.status_code)
print(r.text[:200])
# Out:
# ERROR:    [Errno 98] error while attempting to bind on address ('0.0.0.0', 8000): address already in use
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     34.73.171.6:0 - "GET /docs HTTP/1.1" 200 OK
# 200
#
#     <!DOCTYPE html>
#     <html>
#     <head>
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <link type="text/css" rel="stylesheet" href="https://cdn.jsdelivr.net/npm/swag

# %%
@app.get("/v1/models")
async def list_models():
    return {
        "data": [
            {
                "id": "medgemma",
                "object": "model"
            }
        ]
    }

# %%
@app.get("/health")
async def health():
    return {
        "status": "ok",
        "model": "medgemma"
    }

# %%
from fastapi import Request
from fastapi.responses import JSONResponse
import base64

# %%
def decode_data_url(data_url):
    if "," in data_url:
        data_url = data_url.split(",", 1)[1]

    image_bytes = base64.b64decode(data_url)

    return Image.open(
        BytesIO(image_bytes)
    ).convert("RGB")

# %%
import time
@app.post("/v1/chat/completions")
async def chat_completions(request: Request):

    body = await request.json()

    messages = body.get("messages", [])

    user_content = None

    for msg in messages:
        if msg.get("role") == "user":
            user_content = msg.get("content")
            break

    images = []
    prompt = ""

    if isinstance(user_content, list):

        for item in user_content:

            if item.get("type") == "text":
                prompt = item["text"]

            elif item.get("type") == "image_url":

                images.append(decode_data_url(
                    item["image_url"]["url"]
                ))

    # Strip image placeholder tokens TypeScript may have prepended; Python re-inserts correctly
    clean_prompt = prompt.replace("<start_of_image>", "").replace("", "").strip()

    if images:
        image_tokens = "<start_of_image>" * len(images)
        full_prompt = image_tokens + "\n\n" + clean_prompt + "\n"
    else:
        full_prompt = "\n\n" + clean_prompt + "\n"

    if not images:
        inputs = processor(
            text=full_prompt,
            return_tensors="pt"
        ).to(model.device)
    else:
        inputs = processor(
            text=full_prompt,
            images=images if len(images) > 1 else images[0],
            return_tensors="pt"
        ).to(model.device)

    
    start = time.time()
    
    with torch.inference_mode():
        output = model.generate(
            **inputs,
            max_new_tokens=600,
            do_sample=False,
            repetition_penalty=1.15,
            eos_token_id=processor.tokenizer.eos_token_id,
            pad_token_id=processor.tokenizer.eos_token_id
        )
    
    elapsed = time.time() - start
    
    print(f"Generation time: {elapsed:.2f}s")
    input_len = inputs["input_ids"].shape[1]

    generated_ids = output[0][input_len:]
    
    result = processor.decode(
        generated_ids,
        skip_special_tokens=True
    )
    print("========== MEDGEMMA OUTPUT ==========")
    print(result)
    print("=====================================")
    result = result.strip()

    first = result.find("{")
    last = result.rfind("}")
    
    if first != -1 and last > first:
        result = result[first:last+1]

    return JSONResponse({
        "id": "medgemma",
        "object": "chat.completion",
        "model": "medgemma",
        "choices": [
            {
                "index": 0,
                "message": {
                    "role": "assistant",
                    "content": result
                },
                "finish_reason": "stop"
            }
        ]
    })

# %%
import threading

def run_api():
    uvicorn.run(
        app,
        host="0.0.0.0",
        port=8000
    )

threading.Thread(
    target=run_api,
    daemon=True
).start()

print("API Running")
# Out:
# API Running
# INFO:     Started server process [58]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# ERROR:    [Errno 98] error while attempting to bind on address ('0.0.0.0', 8000): address already in use
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# Generation time: 33.37s
# ========== MEDGEMMA OUTPUT ==========
# ```json
# {
#   "assessment": "Based on your report and the provided X-ray image showing a foreign object or hardware within the wrist/hand area, here is a preliminary assessment:\n\n**Possible Conditions:**\n\n1. **Foreign Body Injury:** The presence of what appears to be a metallic object or surgical implant suggests a potential injury involving a foreign body entering the hand or wrist, possibly during trauma or surgery.\n2. **Post-Surgical Complication:** This could also represent hardware left behind after a previous orthopedic procedure for a fracture or other condition.\n3. **Infection:** While less likely based solely on the X-ray appearance without further clinical information, infection around a foreign body or surgical site can occur.\n4. **Arthritis Flare-up:** Sometimes, underlying joint conditions like arthritis can present with pain and swelling, although the X-ray finding itself points more towards a structural issue.\n\n**Red Flags Requiring Immediate Attention:**\n*   Severe pain radiating up the arm.\n*   Signs of infection such as significant redness, warmth, pus discharge, fever, or chills.\n*   Numbness or tingling in the fingers or hand.\n*   Sudden inability to move the hand or wrist.\n*   If you suspect the object was inserted recently or if there was recent trauma.\n\n**Recommended Tests:**\n*   Complete Blood Count (CBC) - To
# =====================================
# INFO:     103.133.32.32:0 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# Generation time: 32.02s
# ========== MEDGEMMA OUTPUT ==========
# ```json
# {
#   "assessment": "Based on your report and the provided X-ray image showing a foreign object or hardware within the wrist/hand area, here is a preliminary assessment:\n\n**Possible Conditions:**\n\n1. **Foreign Body Injury:** The presence of what appears to be a metallic object or surgical implant suggests a potential injury involving a foreign body entering the hand or wrist, possibly during trauma or surgery.\n2. **Post-Surgical Complication:** This could also represent hardware left behind after a previous orthopedic procedure for a fracture or other condition.\n3. **Infection:** While less likely based solely on the X-ray appearance without further clinical information, infection around a foreign body or surgical site can occur.\n4. **Arthritis Flare-up:** Sometimes, underlying joint conditions like arthritis can present with pain and swelling, although the X-ray finding itself points more towards a structural issue.\n\n**Red Flags Requiring Immediate Attention:**\n*   Severe pain radiating up the arm.\n*   Signs of infection such as significant redness, warmth, pus discharge, fever, or chills.\n*   Numbness or tingling in the fingers or hand.\n*   Sudden inability to move the hand or wrist.\n*   If you suspect the object was inserted recently or if there was recent trauma.\n\n**Recommended Tests:**\n*   Complete Blood Count (CBC) - To
# =====================================
# INFO:     103.133.32.32:0 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# Generation time: 33.80s
# ========== MEDGEMMA OUTPUT ==========
# ```json
# {
#   "assessment": "Based on your report, here's some initial information about potential causes for your symptoms.",
#   "possible_conditions": [
#     "Possible infection",
#     "Possible injury",
#     "Possible allergic reaction",
#     "Possible dehydration/heat exhaustion",
#     "Possible respiratory issue"
#   ],
#   "red_flags": [
#     "Difficulty breathing or shortness of breath",
#     "Chest pain",
#     "High fever unresponsive to medication",
#     "Severe headache or confusion",
#     "Signs of severe bleeding"
#   ],
#   "recommended_tests": [
#     "Complete Blood Count (CBC)",
#     "Dengue NS1 Antigen Test",
#     "Blood Culture",
#     "Urinalysis",
#     "Basic Metabolic Panel (BMP)"
#   ],
#   "recommended_specialist": "General Physician / Internal Medicine Specialist",
#   "disclaimer": "This information is based on limited details provided by you and is not a substitute for professional medical advice. Please consult with a qualified healthcare provider for accurate diagnosis and treatment."
# }
# ```
#
# **Critique:** The user has only provided `cxcscscsss` as input. This is not a valid symptom description. It looks like random characters. Therefore, it's impossible to provide a meaningful assessment.
#
# **Plan:**
# 1. Acknowledge the lack of specific symptoms
# =====================================
# INFO:     103.133.32.32:0 - "POST /v1/chat/completions HTTP/1.1" 200 OK
